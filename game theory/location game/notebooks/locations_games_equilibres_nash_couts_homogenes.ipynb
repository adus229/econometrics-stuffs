# %% [markdown]
# # Locations games avec références avec coûts homogènes

# %%
import random 
from fractions import Fraction
import matplotlib.pyplot as plt
import numpy as np

# %%
message_deviations = "Entrez le nombre de déviations, par défaut il est de 30\nAppuyez sur la touche entrée si vous voulez laisser la valeur par défaut:\n"
message_echelle = "Sur une échelle de combien voulez-vous testez les références(30 par défaut)?\n"
message_success = "Tout est en norme avec la théorie"

# %%
def lancer_programme_ref():
    """
    Lance un mini-programme en console pour simuler les équilibre de Nash en locations games avec références
    """
    #Demander les informations à l'utilisateur
    c = input("Entrez le côut de déviation c qui doit être compris entre 1/2 et 15 : \n")
    n = input(message_echelle)
    nbre_deviations = input(message_deviations)
    #Réécrire les paramètres selon l'entrée de l'utilisateur
    n= 100 if n=='' else int(n)
    nbre_deviations = 30 if nbre_deviations=='' else int(nbre_deviations)
    #Lancer la simulation
    tester_equilibres_ref(c=Fraction(c),n=n,nbre_deviations= int(nbre_deviations))
    
def tester_equilibres_ref(c,n=100,nbre_deviations=100):
    
    grille =np.array([Fraction(x,n) for x in range(0,n+1)]) 
    
    references = []
    
    for r1 in grille :
        #Récupérer uniquement les r2>r1
        grille_r2 = list(filter(lambda x: x>=r1,grille))
        for r2 in grille_r2:
            references.append([r1,r2])
            
    references = np.array(references)
    
    #print("nombre total de références : ", references.shape)
    resultats_dict =  verifier_profile_ref(c,references,nbre_deviations)
    
    resultats=resultats_dict["correct"]
    
    resultats_incorrect = resultats_dict["incorrect"]
    
    x= np.concatenate((resultats[:,0],resultats[:,1]),0)
    y = np.concatenate((resultats[:,1],resultats[:,0]),0)
    c = np.concatenate((resultats[:,2],resultats[:,2]),0)
    
    #Représentation du graphique
    plt.scatter(x,y,c=c,s=1)
    #plt.scatter(resultats[:,0],resultats[:,1],c=resultats[:,2])
    """ plt.title("Nuage de points des références",{
        "fontsize":16,
        "fontweight":25,
        "color": 'r'
    })"""
    plt.xlabel("Références R1")
    plt.ylabel("Références R2")
    plt.show()
    print(message_success)
    
    if resultats_incorrect.size>0:
        print(f'Il y a {resultats_incorrect.shape[0]} pour lesquels on a pas trouvé de déviations : \n',resultats_incorrect)

# %%
def getEquations(c,refs):
    eq1 = c*(refs[:,1]- refs[:,0])**2 +refs[:,1] + refs[:,0] - 1 -delta(c)
    eq2= c*(refs[:,1] - refs[:,0])**2 - (refs[:,1] + refs[:,0]) + 1 - delta(c)
    return eq1,eq2

def delta(c):
    return Fraction(1,4*c) 

def cout_deviation(index_joueur,c,refs,actions_triees,is_ordered):
    return  c*(actions_triees[index_joueur]-refs[index_joueur if is_ordered else 1-index_joueur])**2

# %%
def verifier_profile_ref(c,refs,nbres_deviation =  10):
    """
    Duopole avec reference
        Permet de vérifier la théorie sur l'existence des équilibres de Nash
    Paramètres:
        c: int
            Le côut de déviation, est un entier ou décimal compris entre 0.5 et 15
        refs: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
        nbre_deviation: Représente le nombre de déviation simulé. la valeur par défaut est 10 000
    return: None
    """

    
    #Calcul des bornes
    bornes = np.apply_along_axis(calculs_bornes,1,refs,c)
    
    #sélectionner les bornes du cas 1
    selection_cas1 = bornes[:,0]>=bornes[:,1]
    bornes_cas1 = bornes[selection_cas1]
    refs_cas1 =  refs[selection_cas1]

    #print("références cas 1 : ", refs_cas1.shape)
    
    
    #sélectionner les bornes du cas 2
    """bornes_cas2 = bornes[np.logical_not(selection_cas1)]
    refs_cas2 =  refs[np.logical_not(selection_cas1)]"""
    
    selecteur = bornes[:,0] < bornes[:,1]
    bornes_cas2 = bornes[selecteur]
    refs_cas2 =  refs[selecteur]
    
    #print("références cas 2 : ", refs_cas2.shape)
    result_cas1 = verifier_cas1(c=c,refs=refs_cas1 ,bornes=bornes_cas1,nbres_deviation=nbres_deviation)
    result_cas2 = verifier_cas2(c=c,refs=refs_cas2,bornes=bornes_cas2,nbres_deviation=nbres_deviation)
    
    return {
        "correct": np.concatenate((result_cas1["correct"],result_cas2["correct"]),axis=0),
        "incorrect":np.concatenate((result_cas1["incorrect"],result_cas2["incorrect"]),axis=0)
    }

# %%
def calculs_bornes (references,c):
    """
    Retourne les bornes de décision d'équilibre de Nash pour les joueurs, ie 
    r1 + 1/4c et r2 - 1/4c
    
    paramètres:
        references: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1
    return: tuple
        retourne les bornes        
    """
    refs = sorted(references)
    return refs[0] + delta(c),refs[1] - delta(c)

        
def verifier_cas1(c,refs,bornes,nbres_deviation):
    """
    Duopole avec références:
        Permet de vérifier si le profil (1/2,1/2) est un équilibre de Nash ou pas
    Paramètres:
        c: Le côut de déviation, est un entier ou décimal compris entre 0.5 et 15
        refs: np.array au format (n,2) 
            les références décimales ou fraction compris entre 0 et 1
        bornes: np.array au format (n,2)
            Représente les bornes associées aux différents couple de références
        nbre_deviation: Représente le nombre de déviation simulé 
    return: dict
        les clés sont corrects: pour les références qui matchent bien avec la théorie
        incorrects pour les références dont des déviations appropriées n'ont pas été trouvée pour l'équilibre associée
    """
    
    #Sélectionner les bornes correspondant au cas où 1/2 est équilibre
    selecteur_equilibre = (bornes[:,0]>=Fraction(1,2))&(bornes[:,1]<=Fraction(1,2)) 
    
    #sélectionner les références de l'équilibre
    refs_equilibre = refs[selecteur_equilibre]
    
    
    #Créer les actions notamment 1/2 pour chaques couple de référence
    actions = np.full(shape=refs_equilibre.shape, fill_value=Fraction(1,2))

    #Récupéer les résultats des déviations
    result_deviations = joueurs_peut_devier_ref(c,actions,refs_equilibre,nbres_deviation)

    if np.any(result_deviations):
        #Aucune déviation favorable ne doit être trouvée
        return print("danger de mort 1 1")
    else:
        #Définir les courleurs et rassembler le tout dans un tableau
        colors_equilibre = np.full(shape=(refs_equilibre.shape[0],1), fill_value="orange")
        out_equilibre = np.concatenate((refs_equilibre,colors_equilibre),axis=1)
        
    
    #Le cas où 1/2,1/2 n'est pas un équilibre    
    
    #Sélectionner les références non équilibres
    refs_non_equilibre = refs[np.logical_not(selecteur_equilibre)]
    
    #print("références cas 1 avec 1/2 non équilibre: ", refs_non_equilibre.shape)

    #Créer les actions 1/2 correspondantes
    actions = np.full(shape=refs_non_equilibre.shape, fill_value=Fraction(1,2))
    
    #faire les déviations pour vérifier qu'on trouve bien des déviations favorable
    result_deviations = joueurs_peut_devier_ref(c,actions,refs_non_equilibre,nbres_deviation,False)

    #récupérer les références pour qui des déviations ont été trouvées
    result_corrects = refs_non_equilibre[result_deviations]
        
    #Choisir les couleurs correspondantes
    colors_non_equilibre = np.full(shape=(result_corrects.shape[0],1), fill_value="w")
    out_non_equilibre = np.concatenate((result_corrects,colors_non_equilibre),axis=1)
    
    return {
            "correct": np.concatenate((out_equilibre,out_non_equilibre),axis=0),
            "incorrect": refs_non_equilibre[np.logical_not(result_deviations)] #c'est possible de ne pas trouver des déviations appropriées 
           }

# %%
def verifier_cas2(c,refs,bornes,nbres_deviation):
    """
    Duopole avec références:
        Permet de vérifier si le profil (r1 + 1/4c, r2 - 1/4c) est un équilibre de Nash ou pas
    Paramètres:
        c: Le côut de déviation, est un entier ou décimal compris entre 0.5 et 15
        refs: np.array au format (n,2) 
            les références décimales ou fraction compris entre 0 et 1
        bornes: np.array au format (n,2)
            Représente les bornes associées aux différents couple de références
        nbre_deviation:int
            Représente le nombre de déviation simulé 
    return: dict
        les clés sont corrects: pour les références qui matchent bien avec la théorie
        incorrects pour les références dont des déviations appropriées n'ont pas été trouvée pour l'équilibre associée
    """
        
    #Calculer les équations 1 et 2
    eq1,eq2 = getEquations(c,refs)

    #Selectionner les bornes équilibres
    selecteur_equilibre = (eq1>=0)&(eq2>=0)

    equilibres = bornes[selecteur_equilibre]

    #Les références associées
    refs_equilibre = refs[selecteur_equilibre]

    #print("références cas 2 avec bornes équilibre: ", refs_equilibre.shape)

    #Récupérer les déviations 
    result_deviations = joueurs_peut_devier_ref(c=c,actions=equilibres,
                                                refs=refs_equilibre,
                                               nbre_deviation=nbres_deviation)

    if np.any(result_deviations):
        #ON ne doit pas trouver de déviation favorable
        return print("danger de mort 2 1")
    else:
        colors_equilibre = np.full(shape=(refs_equilibre.shape[0],1), fill_value="b")

        out_equilibre = np.concatenate((refs_equilibre,colors_equilibre),axis=1)


    #Selectionner les références non équilibre            
    refs_non_equilibre = refs[np.logical_not(selecteur_equilibre)]

    #print("références cas 2 avec bornes non équilibre: ", refs_non_equilibre.shape)

    
    actions = bornes[np.logical_not(selecteur_equilibre)]

    result_deviations = joueurs_peut_devier_ref(c=c,
                                                actions=actions,
                                                refs= refs_non_equilibre,
                                                nbre_deviation= nbres_deviation,
                                               tester_equilibre=False)

    #récupérer les références avec déviation favorable
    result_corrects = refs_non_equilibre[result_deviations]

    #Choisir les couleurs correspondantes
    colors_non_equilibre = np.full(shape=(result_corrects.shape[0],1), fill_value="w")
    out_non_equilibre = np.concatenate((result_corrects,colors_non_equilibre),axis=1)

    return {
            "correct": np.concatenate((out_equilibre,out_non_equilibre),axis=0),
            "incorrect": refs_non_equilibre[np.logical_not(result_deviations)]
           }

# %%
def paiement_ref(values,c):
    """
    Calcule le paiement des deux joueurs et renvoie le résultat dans l'ordre des actions
    Paramètres:
        values: list, tuple à 4 éléments les [r1,r2,action1,action2]
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
    return: list [paiement de r1, paiement de r2]
        les paiements des joueurs
    """
    
    refs = values[0:2]
    
    actions = values[2:4]
    #Trier les actions des joueurs
    actions_triees= sorted(actions)
    
    
    #Vérifier si les actions étaient déjà dans le bon ordre
    is_ordered = actions_triees[0] == actions[0]
    
    #Calculer la moyenne des actions
    moyenne = (actions_triees[0]+actions_triees[1])/2 
    
    #calculer le paiement du joueur ayant joué la plus petite action
    paiement_1 = moyenne - cout_deviation(0,c,refs,actions_triees,is_ordered)
    #Calculer le paiement du joueur ayant joué la plus grande action
    paiement_2 = 1- moyenne - cout_deviation(1,c,refs,actions_triees,is_ordered)
    
    """
    Selon que la liste était déjà triée ou pas on retourne les paiements selon l'ordre dans lequel 
    les actions fût envoyées
    """
    if is_ordered:
        return np.array([paiement_1,paiement_2])
    else :
        return np.array([paiement_2,paiement_1])
    
def joueurs_peut_devier_ref(c,actions,refs,nbre_deviation,tester_equilibre=True):
    """
    Retourne une valeur indiquant si un joueur, a une déviation profitable ou non
    Paramètres:
      c: int, float
            Le côut de déviation doit compris entre 0.5 et 15
        actions: list, tuple
            le profil d'actions des joueurs
        refs: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
    return: boolean,dict
        Retourne False, si aucun joueurs n'a de déviation profitable possible
        Un dict, si un joueur a une déviation profitable possible
    """
    #Le paiement des joueurs à l'équilibre
    
    values = np.concatenate((refs,actions),axis=1)
    
    result_deviations  = np.apply_along_axis(simuler_deviation,1,values,c,nbre_deviation,tester_equilibre)
    
    return result_deviations
    
def simuler_deviation(values,c,nbre_deviation,tester_equilibre):
    """
    Paramètres:
        values: list, tuple à 4 éléments les [r1,r2,action1,action2]
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
        c: int, float
            Le côut de déviation doit compris entre 0.5 et 15
        nbre_deviation:int
            Représente le nombre de déviation simulé 
    return: boolean
        true si une déviation favorable a été trouvé pour un joueur
        false sinon
    """
    

    refs = values[0:2]
    
    actions = values[2:4]
         
    
    #Tirer au hasard des déviations
    deviations = np.random.uniform(0,1,size=(1,round(nbre_deviation-8)))
    
    #Convertir en fraction 
    deviations = np.apply_along_axis(lambda x : Fraction(x[0]),axis=0,arr=deviations)
    
    #Garantir les déviations locales pour les déviations pour ldes cas particuliers
    deviations_locales = np.array([actions[0]-Fraction("10e-12"),actions[0]+Fraction("10e-12"),
                                            actions[1]-Fraction("10e-12"),actions[1]+Fraction("10e-12")
                                          ])    
                 

    #Calculer le paiement à l'équilibre
    paiements_equilibre  = paiement_ref(values,c)
     
    if tester_equilibre:
        

        #Joindre les déviations locales avec celles aléatoires
        deviations = np.concatenate((deviations_locales,deviations,deviations_locales),0)
        
        #Tirer au hasard un joueur pour deviations_locales_joueur1la déviation
        nombre_de_1 = sum(np.random.randint(0,2,size = deviations.size))
    
        #Créer un tableau avec les déviations
        profil_deviation = np.array(np.broadcast_to(values,shape=(deviations.size,values.size))) 

        #Faire dévier aléatoirement les joueurs 1 et 2
        profil_deviation[:nombre_de_1,2]=deviations[:nombre_de_1]

        profil_deviation[nombre_de_1:,3]=deviations[nombre_de_1:]
        

        #Calculer les paiements après déviations
        paiements_deviation= np.apply_along_axis(paiement_ref,1,profil_deviation,c)
    
        
        result_deviation_1 = paiements_equilibre[0]<paiements_deviation[:nombre_de_1,0]

        result_deviation_2=paiements_equilibre[1]<paiements_deviation[nombre_de_1:,1]

        return np.any(result_deviation_1) or np.any(result_deviation_2)
    else: #Si le profil n'est pas un équilibre on teste d'abord les déviations locales
        
        profil_deviation = np.array(np.broadcast_to(values,shape=(deviations_locales.size*2,values.size)))  
        
        nombre_de_1 = deviations_locales.size
        
                #Faire dévier aléatoirement les joueurs 1 et 2
        profil_deviation[:nombre_de_1,2]=deviations_locales
        
        profil_deviation[nombre_de_1:,3]=deviations_locales
        
        #Calculer les paiements après déviations
        paiements_deviation= np.apply_along_axis(paiement_ref,1,profil_deviation,c)
        
        result_deviation_1 = paiements_equilibre[0]<paiements_deviation[:nombre_de_1,0]

        result_deviation_2=paiements_equilibre[1]<paiements_deviation[nombre_de_1:,1]
        
        if np.any(result_deviation_1) or np.any(result_deviation_2):
            return True
        #Si la déviation locale ne suffit pas pour prouver que le profil n'est pas un équilibre on teste celle globale 
        else:
                    #Tirer au hasard un joueur pour deviations_locales_joueur1la déviation
            nombre_de_1 = sum(np.random.randint(0,2,size = deviations.size))

            #Créer un tableau avec les déviations
            profil_deviation = np.array(np.broadcast_to(values,shape=(deviations.size,values.size))) 
            
   
            #Faire dévier aléatoirement les joueurs 1 et 2
            profil_deviation[:nombre_de_1,2]=deviations[:nombre_de_1]

            profil_deviation[nombre_de_1:,3]=deviations[nombre_de_1:]


            #Calculer les paiements après déviations
            paiements_deviation= np.apply_along_axis(paiement_ref,1,profil_deviation,c)


            result_deviation_1 = paiements_equilibre[0]<paiements_deviation[:nombre_de_1,0]

            result_deviation_2=paiements_equilibre[1]<paiements_deviation[nombre_de_1:,1]
            
            return np.any(result_deviation_1) or np.any(result_deviation_2)
         
    
def get_message_danger(result):
    """
    Message envoyé dans le cas où on trouve une contradictionavec la théorie
    """
    return """
    *************Données**********
    Références:        {result[refs]}
    actions:           {result[actions]}
    côut de défiation: {result[c]}
    ******************************
    Le joueurs {joueur} ayant pour référence {result[reference]} et ayant joué {action_joueur}  peut dévier
    vers: {result[deviation]}
    Son paiement sans déviation est: {result[paiement_equilibre]}
    Son paiement après déviation est: {result[paiement_deviation]}
    """.format(result=result,action_joueur=result["actions"][result["joueur"]],joueur=result["joueur"]+1)

# %%
calculs_bornes([Fraction(1,2),Fraction(1,2)],1)
# Out:
# (Fraction(3, 4), Fraction(1, 4))

# %%
tester_equilibres_ref(1,150,30)
# Out:
# Tout est en norme avec la théorie

# %%
for c in [ Fraction("0.7"), Fraction("0.9"), Fraction("1.5"),5,15]:
    tester_equilibres_ref(c,150,30)
# Out:
# Tout est en norme avec la théorie
# Tout est en norme avec la théorie
# Tout est en norme avec la théorie
# Tout est en norme avec la théorie
# Tout est en norme avec la théorie

# %%
lancer_programme_ref()
# Out:
# Entrez le côut de déviation c qui doit être compris entre 1/2 et 15 :
# 3
# Sur une échelle de combien voulez-vous testez les références(30 par défaut)?
#
# Entrez le nombre de déviations, par défaut il est de 30
# Appuyez sur la touche entrée si vous voulez laisser la valeur par défaut:
#
# références cas 1 avec 1/2 équilibre:  (153, 2)
# Tout est en norme avec la théorie

# %%
tester_equilibres_ref(1,nbre_deviations=30)
# Out:
# danger de mort 1 1
# danger de mort 2 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-248-9c8a97bf2366> in <module>
# ----> 1 tester_equilibres_ref(1,nbre_deviations=30)
#
# <ipython-input-232-a37c83b7beb6> in tester_equilibres_ref(c, n, nbre_deviations)
#      28
#      29     #print("nombre total de références : ", references.shape)
# ---> 30     resultats_dict =  verifier_profile_ref(c,references,nbre_deviations)
#      31
#      32     resultats=resultats_dict["correct"]
#
# <ipython-input-233-8f7c06aa0fe1> in verifier_profile_ref(c, refs, nbres_deviation)
#      37
#      38     return {
# ---> 39         "correct": np.concatenate((result_cas1["correct"],result_cas2["correct"]),axis=0),
#      40         "incorrect":np.concatenate((result_cas1["incorrect"],result_cas2["incorrect"]),axis=0)
#      41     }
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # Equilibre symétriques

# %%
def getEquations(c,refs):
    eq1 = c*(refs[:,1]- refs[:,0]-Fraction(1,2))**2 +refs[:,1] + refs[:,0] - 1 - (delta(c))
    eq2= c*(refs[:,1] - refs[:,0]-Fraction(1,2))**2 - (refs[:,1] + refs[:,0]) + 1 - (delta(c))
    return eq1,eq2

def delta(c):
    return Fraction(1,4*c)#+ Fraction(1,2)

def cout_deviation(index_joueur,c,refs,actions_triees,is_ordered):
    return  c*(actions_triees[index_joueur]-refs[index_joueur if is_ordered else 1-index_joueur]-Fraction(1,2))**2

# %%
def tester_equilibre_symetrique(c,n=100,nbre_deviations=100,graphique=True):
    grille =np.array([Fraction(x,2*n) for x in range(0,n+1)]) 

    references = []

    for r1 in grille :
        r2 = 1-r1
        references.append([r1,r2])

    references = np.array(references)

    #Calcul des bornes
    bornes = np.apply_along_axis(calculs_bornes,1,references,c)

    #sélectionner les bornes du cas 1
    selection_cas1 = bornes[:,0]>=bornes[:,1]
    refs_cas1 =  references[selection_cas1]

    #Création des actions
    actions1 = np.full(shape=(refs_cas1.shape[0],2),fill_value=Fraction(1,2))

    matrice_cas1 = np.concatenate((refs_cas1,actions1),1)

    #sélectionner les bornes du cas 2
    actions2 = bornes[np.logical_not(selection_cas1)]
    refs_cas2 =  references[np.logical_not(selection_cas1)]

    matrice_cas2 = np.concatenate((refs_cas2,actions2),1)

    matrice_profile = np.concatenate((matrice_cas1,matrice_cas2),0)

    paiements= np.apply_along_axis(paiement_ref,1,matrice_profile,c)
    
    paiement_max =  np.max(paiements[:,0])

    
    refs_maximum = matrice_profile[paiements[:,0]==paiement_max,0]
    

    actions_max = matrice_profile[paiements[:,0]==paiement_max,2:4]

    if graphique:
        #Représentation du graphique
        plt.subplot(211)
        plt.title("Joueur1")
        plt.plot(references[:,0],paiements[:,0])
        plt.xlabel("Références r1")
        plt.ylabel("paiements")
        plt.show()

        plt.subplot(212)
        plt.plot(references[:,0],paiements[:,1])
        plt.title("Joueur2")
        plt.xlabel("Références r1")
        plt.ylabel("paiements")
        plt.show()

    return {
        "paiement_max":np.array(paiement_max),
        "refs_max":np.array(refs_maximum),
        "actions_max":np.array(actions_max)}

# %%
tester_equilibres_ref(1,nbre_deviations=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-227-9c8a97bf2366> in <module>
# ----> 1 tester_equilibres_ref(1,nbre_deviations=30)
#
# <ipython-input-225-9e81ad440a3f> in tester_equilibres_ref(c, n, nbre_deviations)
#      11
#      12     #print("nombre total de références : ", references.shape)
# ---> 13     resultats_dict =  verifier_profile_ref(c,references,nbre_deviations)
#      14
#      15     resultats=resultats_dict["correct"]
#
# <ipython-input-218-8f7c06aa0fe1> in verifier_profile_ref(c, refs, nbres_deviation)
#      33
#      34     #print("références cas 2 : ", refs_cas2.shape)
# ---> 35     result_cas1 = verifier_cas1(c=c,refs=refs_cas1 ,bornes=bornes_cas1,nbres_deviation=nbres_deviation)
#      36     result_cas2 = verifier_cas2(c=c,refs=refs_cas2,bornes=bornes_cas2,nbres_deviation=nbres_deviation)
#      37
#
# <ipython-input-219-49014da8c564> in verifier_cas1(c, refs, bornes, nbres_deviation)
#      41
#      42     #Récupéer les résultats des déviations
# ---> 43     result_deviations = joueurs_peut_devier_ref(c,actions,refs_equilibre,nbres_deviation)
#      44
#      45     if np.any(result_deviations):
#
# <ipython-input-221-6e7972042c26> in joueurs_peut_devier_ref(c, actions, refs, nbre_deviation, tester_equilibre)
#      54     values = np.concatenate((refs,actions),axis=1)
#      55
# ---> 56     result_deviations  = np.apply_along_axis(simuler_deviation,1,values,c,nbre_deviation,tester_equilibre)
#      57
#      58     return result_deviations
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     374         ind0 = next(inds)
#     375     except StopIteration as e:
# --> 376         raise ValueError(
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
#
# ValueError: Cannot apply_along_axis when any iteration dimensions are 0

# %%
tester_equilibre_symetrique(1)
# Out:
# {'paiement_max': array(Fraction(7, 16), dtype=object),
#  'refs_max': array([Fraction(1, 4), Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#         Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#         Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#         Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#         Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#         Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#         Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#         Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#         Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#         Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#         Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#         Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#         Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#         Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#         Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#         Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#         Fraction(6, 25), Fraction(49, 200)], dtype=object),
#  'actions_max': array([[Fraction(1, 2), Fraction(1, 2)],
#         [Fraction(1, 4), Fraction(3, 4)],
#         [Fraction(51, 200), Fraction(149, 200)],
#         [Fraction(13, 50), Fraction(37, 50)],
#         [Fraction(53, 200), Fraction(147, 200)],
#         [Fraction(27, 100), Fraction(73, 100)],
#         [Fraction(11, 40), Fraction(29, 40)],
#         [Fraction(7, 25), Fraction(18, 25)],
#         [Fraction(57, 200), Fraction(143, 200)],
#         [Fraction(29, 100), Fraction(71, 100)],
#         [Fraction(59, 200), Fraction(141, 200)],
#         [Fraction(3, 10), Fraction(7, 10)],
#         [Fraction(61, 200), Fraction(139, 200)],
#         [Fraction(31, 100), Fraction(69, 100)],
#         [Fraction(63, 200), Fraction(137, 200)],
#         [Fraction(8, 25), Fraction(17, 25)],
#         [Fraction(13, 40), Fraction(27, 40)],
#         [Fraction(33, 100), Fraction(67, 100)],
#         [Fraction(67, 200), Fraction(133, 200)],
#         [Fraction(17, 50), Fraction(33, 50)],
#         [Fraction(69, 200), Fraction(131, 200)],
#         [Fraction(7, 20), Fraction(13, 20)],
#         [Fraction(71, 200), Fraction(129, 200)],
#         [Fraction(9, 25), Fraction(16, 25)],
#         [Fraction(73, 200), Fraction(127, 200)],
#         [Fraction(37, 100), Fraction(63, 100)],
#         [Fraction(3, 8), Fraction(5, 8)],
#         [Fraction(19, 50), Fraction(31, 50)],
#         [Fraction(77, 200), Fraction(123, 200)],
#         [Fraction(39, 100), Fraction(61, 100)],
#         [Fraction(79, 200), Fraction(121, 200)],
#         [Fraction(2, 5), Fraction(3, 5)],
#         [Fraction(81, 200), Fraction(119, 200)],
#         [Fraction(41, 100), Fraction(59, 100)],
#         [Fraction(83, 200), Fraction(117, 200)],
#         [Fraction(21, 50), Fraction(29, 50)],
#         [Fraction(17, 40), Fraction(23, 40)],
#         [Fraction(43, 100), Fraction(57, 100)],
#         [Fraction(87, 200), Fraction(113, 200)],
#         [Fraction(11, 25), Fraction(14, 25)],
#         [Fraction(89, 200), Fraction(111, 200)],
#         [Fraction(9, 20), Fraction(11, 20)],
#         [Fraction(91, 200), Fraction(109, 200)],
#         [Fraction(23, 50), Fraction(27, 50)],
#         [Fraction(93, 200), Fraction(107, 200)],
#         [Fraction(47, 100), Fraction(53, 100)],
#         [Fraction(19, 40), Fraction(21, 40)],
#         [Fraction(12, 25), Fraction(13, 25)],
#         [Fraction(97, 200), Fraction(103, 200)],
#         [Fraction(49, 100), Fraction(51, 100)],
#         [Fraction(99, 200), Fraction(101, 200)]], dtype=object)}

# %%
paiements_max=[]
refs =[]
actions=[]
couts = range(1,200)
for c in couts:
    result = tester_equilibre_symetrique(c,graphique=False)
    paiements_max.append(result["paiement_max"])
    refs.append(result["refs_max"])
    actions.append(result["actions_max"])
plt.plot(couts,paiements_max)
plt.xlabel("Coûts de déviation")
plt.ylabel("Paiements des joueurs")
plt.show()

print(np.array(refs))
print("\n\n\n")
print(np.array(actions))
# Out:
# [array([Fraction(1, 4), Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200)], dtype=object)
#  array([Fraction(3, 8), Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100)],
#       dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200)],
#       dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200)], dtype=object)
#  array([Fraction(9, 20), Fraction(0, 1), Fraction(1, 200),
#        Fraction(1, 100), Fraction(3, 200), Fraction(1, 50),
#        Fraction(1, 40), Fraction(3, 100), Fraction(7, 200),
#        Fraction(1, 25), Fraction(9, 200), Fraction(1, 20),
#        Fraction(11, 200), Fraction(3, 50), Fraction(13, 200),
#        Fraction(7, 100), Fraction(3, 40), Fraction(2, 25),
#        Fraction(17, 200), Fraction(9, 100), Fraction(19, 200),
#        Fraction(1, 10), Fraction(21, 200), Fraction(11, 100),
#        Fraction(23, 200), Fraction(3, 25), Fraction(1, 8),
#        Fraction(13, 100), Fraction(27, 200), Fraction(7, 50),
#        Fraction(29, 200), Fraction(3, 20), Fraction(31, 200),
#        Fraction(4, 25), Fraction(33, 200), Fraction(17, 100),
#        Fraction(7, 40), Fraction(9, 50), Fraction(37, 200),
#        Fraction(19, 100), Fraction(39, 200), Fraction(1, 5),
#        Fraction(41, 200), Fraction(21, 100), Fraction(43, 200),
#        Fraction(11, 50), Fraction(9, 40), Fraction(23, 100),
#        Fraction(47, 200), Fraction(6, 25), Fraction(49, 200),
#        Fraction(1, 4), Fraction(51, 200), Fraction(13, 50),
#        Fraction(53, 200), Fraction(27, 100), Fraction(11, 40),
#        Fraction(7, 25), Fraction(57, 200), Fraction(29, 100),
#        Fraction(59, 200), Fraction(3, 10), Fraction(61, 200),
#        Fraction(31, 100), Fraction(63, 200), Fraction(8, 25),
#        Fraction(13, 40), Fraction(33, 100), Fraction(67, 200),
#        Fraction(17, 50), Fraction(69, 200), Fraction(7, 20),
#        Fraction(71, 200), Fraction(9, 25), Fraction(73, 200),
#        Fraction(37, 100), Fraction(3, 8), Fraction(19, 50),
#        Fraction(77, 200), Fraction(39, 100), Fraction(79, 200),
#        Fraction(2, 5), Fraction(81, 200), Fraction(41, 100),
#        Fraction(83, 200), Fraction(21, 50), Fraction(17, 40),
#        Fraction(43, 100), Fraction(87, 200), Fraction(11, 25),
#        Fraction(89, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100)], dtype=object)
#  array([Fraction(19, 40), Fraction(0, 1), Fraction(1, 200),
#        Fraction(1, 100), Fraction(3, 200), Fraction(1, 50),
#        Fraction(1, 40), Fraction(3, 100), Fraction(7, 200),
#        Fraction(1, 25), Fraction(9, 200), Fraction(1, 20),
#        Fraction(11, 200), Fraction(3, 50), Fraction(13, 200),
#        Fraction(7, 100), Fraction(3, 40), Fraction(2, 25),
#        Fraction(17, 200), Fraction(9, 100), Fraction(19, 200),
#        Fraction(1, 10), Fraction(21, 200), Fraction(11, 100),
#        Fraction(23, 200), Fraction(3, 25), Fraction(1, 8),
#        Fraction(13, 100), Fraction(27, 200), Fraction(7, 50),
#        Fraction(29, 200), Fraction(3, 20), Fraction(31, 200),
#        Fraction(4, 25), Fraction(33, 200), Fraction(17, 100),
#        Fraction(7, 40), Fraction(9, 50), Fraction(37, 200),
#        Fraction(19, 100), Fraction(39, 200), Fraction(1, 5),
#        Fraction(41, 200), Fraction(21, 100), Fraction(43, 200),
#        Fraction(11, 50), Fraction(9, 40), Fraction(23, 100),
#        Fraction(47, 200), Fraction(6, 25), Fraction(49, 200),
#        Fraction(1, 4), Fraction(51, 200), Fraction(13, 50),
#        Fraction(53, 200), Fraction(27, 100), Fraction(11, 40),
#        Fraction(7, 25), Fraction(57, 200), Fraction(29, 100),
#        Fraction(59, 200), Fraction(3, 10), Fraction(61, 200),
#        Fraction(31, 100), Fraction(63, 200), Fraction(8, 25),
#        Fraction(13, 40), Fraction(33, 100), Fraction(67, 200),
#        Fraction(17, 50), Fraction(69, 200), Fraction(7, 20),
#        Fraction(71, 200), Fraction(9, 25), Fraction(73, 200),
#        Fraction(37, 100), Fraction(3, 8), Fraction(19, 50),
#        Fraction(77, 200), Fraction(39, 100), Fraction(79, 200),
#        Fraction(2, 5), Fraction(81, 200), Fraction(41, 100),
#        Fraction(83, 200), Fraction(21, 50), Fraction(17, 40),
#        Fraction(43, 100), Fraction(87, 200), Fraction(11, 25),
#        Fraction(89, 200), Fraction(9, 20), Fraction(91, 200),
#        Fraction(23, 50), Fraction(93, 200), Fraction(47, 100)],
#       dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40)],
#       dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40)],
#       dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(0, 1), Fraction(1, 200), Fraction(1, 100),
#        Fraction(3, 200), Fraction(1, 50), Fraction(1, 40),
#        Fraction(3, 100), Fraction(7, 200), Fraction(1, 25),
#        Fraction(9, 200), Fraction(1, 20), Fraction(11, 200),
#        Fraction(3, 50), Fraction(13, 200), Fraction(7, 100),
#        Fraction(3, 40), Fraction(2, 25), Fraction(17, 200),
#        Fraction(9, 100), Fraction(19, 200), Fraction(1, 10),
#        Fraction(21, 200), Fraction(11, 100), Fraction(23, 200),
#        Fraction(3, 25), Fraction(1, 8), Fraction(13, 100),
#        Fraction(27, 200), Fraction(7, 50), Fraction(29, 200),
#        Fraction(3, 20), Fraction(31, 200), Fraction(4, 25),
#        Fraction(33, 200), Fraction(17, 100), Fraction(7, 40),
#        Fraction(9, 50), Fraction(37, 200), Fraction(19, 100),
#        Fraction(39, 200), Fraction(1, 5), Fraction(41, 200),
#        Fraction(21, 100), Fraction(43, 200), Fraction(11, 50),
#        Fraction(9, 40), Fraction(23, 100), Fraction(47, 200),
#        Fraction(6, 25), Fraction(49, 200), Fraction(1, 4),
#        Fraction(51, 200), Fraction(13, 50), Fraction(53, 200),
#        Fraction(27, 100), Fraction(11, 40), Fraction(7, 25),
#        Fraction(57, 200), Fraction(29, 100), Fraction(59, 200),
#        Fraction(3, 10), Fraction(61, 200), Fraction(31, 100),
#        Fraction(63, 200), Fraction(8, 25), Fraction(13, 40),
#        Fraction(33, 100), Fraction(67, 200), Fraction(17, 50),
#        Fraction(69, 200), Fraction(7, 20), Fraction(71, 200),
#        Fraction(9, 25), Fraction(73, 200), Fraction(37, 100),
#        Fraction(3, 8), Fraction(19, 50), Fraction(77, 200),
#        Fraction(39, 100), Fraction(79, 200), Fraction(2, 5),
#        Fraction(81, 200), Fraction(41, 100), Fraction(83, 200),
#        Fraction(21, 50), Fraction(17, 40), Fraction(43, 100),
#        Fraction(87, 200), Fraction(11, 25), Fraction(89, 200),
#        Fraction(9, 20), Fraction(91, 200), Fraction(23, 50),
#        Fraction(93, 200), Fraction(47, 100), Fraction(19, 40),
#        Fraction(12, 25), Fraction(97, 200)], dtype=object)
#  array([Fraction(49, 100), Fraction(0, 1), Fraction(1, 200),
#        Fraction(1, 100), Fraction(3, 200), Fraction(1, 50),
#        Fraction(1, 40), Fraction(3, 100), Fraction(7, 200),
#        Fraction(1, 25), Fraction(9, 200), Fraction(1, 20),
#        Fraction(11, 200), Fraction(3, 50), Fraction(13, 200),
#        Fraction(7, 100), Fraction(3, 40), Fraction(2, 25),
#        Fraction(17, 200), Fraction(9, 100), Fraction(19, 200),
#        Fraction(1, 10), Fraction(21, 200), Fraction(11, 100),
#        Fraction(23, 200), Fraction(3, 25), Fraction(1, 8),
#        Fraction(13, 100), Fraction(27, 200), Fraction(7, 50),
#        Fraction(29, 200), Fraction(3, 20), Fraction(31, 200),
#        Fraction(4, 25), Fraction(33, 200), Fraction(17, 100),
#        Fraction(7, 40), Fraction(9, 50), Fraction(37, 200),
#        Fraction(19, 100), Fraction(39, 200), Fraction(1, 5),
#        Fraction(41, 200), Fraction(21, 100), Fraction(43, 200),
#        Fraction(11, 50), Fraction(9, 40), Fraction(23, 100),
#        Fraction(47, 200), Fraction(6, 25), Fraction(49, 200),
#        Fraction(1, 4), Fraction(51, 200), Fraction(13, 50),
#        Fraction(53, 200), Fraction(27, 100), Fraction(11, 40),
#        Fraction(7, 25), Fraction(57, 200), Fraction(29, 100),
#        Fraction(59, 200), Fraction(3, 10), Fraction(61, 200),
#        Fraction(31, 100), Fraction(63, 200), Fraction(8, 25),
#        Fraction(13, 40), Fraction(33, 100), Fraction(67, 200),
#        Fraction(17, 50), Fraction(69, 200), Fraction(7, 20),
#        Fraction(71, 200), Fraction(9, 25), Fraction(73, 200),
#        Fraction(37, 100), Fraction(3, 8), Fraction(19, 50),
#        Fraction(77, 200), Fraction(39, 100), Fraction(79, 200),
#        Fraction(2, 5), Fraction(81, 200), Fraction(41, 100),
#        Fraction(83, 200), Fraction(21, 50), Fraction(17, 40),
#        Fraction(43, 100), Fraction(87, 200), Fraction(11, 25),
#        Fraction(89, 200), Fraction(9, 20), Fraction(91, 200),
#        Fraction(23, 50), Fraction(93, 200), Fraction(47, 100),
# ...
#        [Fraction(3793, 39400), Fraction(35607, 39400)],
#        [Fraction(399, 3940), Fraction(3541, 3940)],
#        [Fraction(4187, 39400), Fraction(35213, 39400)],
#        [Fraction(548, 4925), Fraction(4377, 4925)],
#        [Fraction(4581, 39400), Fraction(34819, 39400)],
#        [Fraction(2389, 19700), Fraction(17311, 19700)],
#        [Fraction(199, 1576), Fraction(1377, 1576)],
#        [Fraction(1293, 9850), Fraction(8557, 9850)],
#        [Fraction(5369, 39400), Fraction(34031, 39400)],
#        [Fraction(2783, 19700), Fraction(16917, 19700)],
#        [Fraction(5763, 39400), Fraction(33637, 39400)],
#        [Fraction(149, 985), Fraction(836, 985)],
#        [Fraction(6157, 39400), Fraction(33243, 39400)],
#        [Fraction(3177, 19700), Fraction(16523, 19700)],
#        [Fraction(6551, 39400), Fraction(32849, 39400)],
#        [Fraction(1687, 9850), Fraction(8163, 9850)],
#        [Fraction(1389, 7880), Fraction(6491, 7880)],
#        [Fraction(3571, 19700), Fraction(16129, 19700)],
#        [Fraction(7339, 39400), Fraction(32061, 39400)],
#        [Fraction(942, 4925), Fraction(3983, 4925)],
#        [Fraction(7733, 39400), Fraction(31667, 39400)],
#        [Fraction(793, 3940), Fraction(3147, 3940)],
#        [Fraction(8127, 39400), Fraction(31273, 39400)],
#        [Fraction(2081, 9850), Fraction(7769, 9850)],
#        [Fraction(8521, 39400), Fraction(30879, 39400)],
#        [Fraction(4359, 19700), Fraction(15341, 19700)],
#        [Fraction(1783, 7880), Fraction(6097, 7880)],
#        [Fraction(1139, 4925), Fraction(3786, 4925)],
#        [Fraction(9309, 39400), Fraction(30091, 39400)],
#        [Fraction(4753, 19700), Fraction(14947, 19700)],
#        [Fraction(9703, 39400), Fraction(29697, 39400)],
#        [Fraction(99, 394), Fraction(295, 394)],
#        [Fraction(10097, 39400), Fraction(29303, 39400)],
#        [Fraction(5147, 19700), Fraction(14553, 19700)],
#        [Fraction(10491, 39400), Fraction(28909, 39400)],
#        [Fraction(1336, 4925), Fraction(3589, 4925)],
#        [Fraction(2177, 7880), Fraction(5703, 7880)],
#        [Fraction(5541, 19700), Fraction(14159, 19700)],
#        [Fraction(11279, 39400), Fraction(28121, 39400)],
#        [Fraction(2869, 9850), Fraction(6981, 9850)],
#        [Fraction(11673, 39400), Fraction(27727, 39400)],
#        [Fraction(1187, 3940), Fraction(2753, 3940)],
#        [Fraction(12067, 39400), Fraction(27333, 39400)],
#        [Fraction(1533, 4925), Fraction(3392, 4925)],
#        [Fraction(12461, 39400), Fraction(26939, 39400)],
#        [Fraction(6329, 19700), Fraction(13371, 19700)],
#        [Fraction(2571, 7880), Fraction(5309, 7880)],
#        [Fraction(3263, 9850), Fraction(6587, 9850)],
#        [Fraction(13249, 39400), Fraction(26151, 39400)],
#        [Fraction(6723, 19700), Fraction(12977, 19700)],
#        [Fraction(13643, 39400), Fraction(25757, 39400)],
#        [Fraction(346, 985), Fraction(639, 985)],
#        [Fraction(14037, 39400), Fraction(25363, 39400)],
#        [Fraction(7117, 19700), Fraction(12583, 19700)],
#        [Fraction(14431, 39400), Fraction(24969, 39400)],
#        [Fraction(3657, 9850), Fraction(6193, 9850)],
#        [Fraction(593, 1576), Fraction(983, 1576)],
#        [Fraction(7511, 19700), Fraction(12189, 19700)],
#        [Fraction(15219, 39400), Fraction(24181, 39400)],
#        [Fraction(1927, 4925), Fraction(2998, 4925)],
#        [Fraction(15613, 39400), Fraction(23787, 39400)],
#        [Fraction(1581, 3940), Fraction(2359, 3940)],
#        [Fraction(16007, 39400), Fraction(23393, 39400)],
#        [Fraction(4051, 9850), Fraction(5799, 9850)],
#        [Fraction(16401, 39400), Fraction(22999, 39400)],
#        [Fraction(8299, 19700), Fraction(11401, 19700)],
#        [Fraction(3359, 7880), Fraction(4521, 7880)],
#        [Fraction(2124, 4925), Fraction(2801, 4925)],
#        [Fraction(17189, 39400), Fraction(22211, 39400)],
#        [Fraction(8693, 19700), Fraction(11007, 19700)],
#        [Fraction(17583, 39400), Fraction(21817, 39400)],
#        [Fraction(889, 1970), Fraction(1081, 1970)],
#        [Fraction(17977, 39400), Fraction(21423, 39400)],
#        [Fraction(9087, 19700), Fraction(10613, 19700)],
#        [Fraction(18371, 39400), Fraction(21029, 39400)],
#        [Fraction(2321, 4925), Fraction(2604, 4925)],
#        [Fraction(3753, 7880), Fraction(4127, 7880)],
#        [Fraction(9481, 19700), Fraction(10219, 19700)],
#        [Fraction(19159, 39400), Fraction(20241, 39400)],
#        [Fraction(4839, 9850), Fraction(5011, 9850)],
#        [Fraction(19553, 39400), Fraction(19847, 39400)]], dtype=object)
#  array([[Fraction(1, 792), Fraction(791, 792)],
#        [Fraction(31, 4950), Fraction(4919, 4950)],
#        [Fraction(223, 19800), Fraction(19577, 19800)],
#        [Fraction(161, 9900), Fraction(9739, 9900)],
#        [Fraction(421, 19800), Fraction(19379, 19800)],
#        [Fraction(13, 495), Fraction(482, 495)],
#        [Fraction(619, 19800), Fraction(19181, 19800)],
#        [Fraction(359, 9900), Fraction(9541, 9900)],
#        [Fraction(817, 19800), Fraction(18983, 19800)],
#        [Fraction(229, 4950), Fraction(4721, 4950)],
#        [Fraction(203, 3960), Fraction(3757, 3960)],
#        [Fraction(557, 9900), Fraction(9343, 9900)],
#        [Fraction(1213, 19800), Fraction(18587, 19800)],
#        [Fraction(164, 2475), Fraction(2311, 2475)],
#        [Fraction(1411, 19800), Fraction(18389, 19800)],
#        [Fraction(151, 1980), Fraction(1829, 1980)],
#        [Fraction(1609, 19800), Fraction(18191, 19800)],
#        [Fraction(427, 4950), Fraction(4523, 4950)],
#        [Fraction(1807, 19800), Fraction(17993, 19800)],
#        [Fraction(953, 9900), Fraction(8947, 9900)],
#        [Fraction(401, 3960), Fraction(3559, 3960)],
#        [Fraction(263, 2475), Fraction(2212, 2475)],
#        [Fraction(2203, 19800), Fraction(17597, 19800)],
#        [Fraction(1151, 9900), Fraction(8749, 9900)],
#        [Fraction(2401, 19800), Fraction(17399, 19800)],
#        [Fraction(25, 198), Fraction(173, 198)],
#        [Fraction(2599, 19800), Fraction(17201, 19800)],
#        [Fraction(1349, 9900), Fraction(8551, 9900)],
#        [Fraction(2797, 19800), Fraction(17003, 19800)],
#        [Fraction(362, 2475), Fraction(2113, 2475)],
#        [Fraction(599, 3960), Fraction(3361, 3960)],
#        [Fraction(1547, 9900), Fraction(8353, 9900)],
#        [Fraction(3193, 19800), Fraction(16607, 19800)],
#        [Fraction(823, 4950), Fraction(4127, 4950)],
#        [Fraction(3391, 19800), Fraction(16409, 19800)],
#        [Fraction(349, 1980), Fraction(1631, 1980)],
#        [Fraction(3589, 19800), Fraction(16211, 19800)],
#        [Fraction(461, 2475), Fraction(2014, 2475)],
#        [Fraction(3787, 19800), Fraction(16013, 19800)],
#        [Fraction(1943, 9900), Fraction(7957, 9900)],
#        [Fraction(797, 3960), Fraction(3163, 3960)],
#        [Fraction(1021, 4950), Fraction(3929, 4950)],
#        [Fraction(4183, 19800), Fraction(15617, 19800)],
#        [Fraction(2141, 9900), Fraction(7759, 9900)],
#        [Fraction(4381, 19800), Fraction(15419, 19800)],
#        [Fraction(112, 495), Fraction(383, 495)],
#        [Fraction(4579, 19800), Fraction(15221, 19800)],
#        [Fraction(2339, 9900), Fraction(7561, 9900)],
#        [Fraction(4777, 19800), Fraction(15023, 19800)],
#        [Fraction(1219, 4950), Fraction(3731, 4950)],
#        [Fraction(199, 792), Fraction(593, 792)],
#        [Fraction(2537, 9900), Fraction(7363, 9900)],
#        [Fraction(5173, 19800), Fraction(14627, 19800)],
#        [Fraction(659, 2475), Fraction(1816, 2475)],
#        [Fraction(5371, 19800), Fraction(14429, 19800)],
#        [Fraction(547, 1980), Fraction(1433, 1980)],
#        [Fraction(5569, 19800), Fraction(14231, 19800)],
#        [Fraction(1417, 4950), Fraction(3533, 4950)],
#        [Fraction(5767, 19800), Fraction(14033, 19800)],
#        [Fraction(2933, 9900), Fraction(6967, 9900)],
#        [Fraction(1193, 3960), Fraction(2767, 3960)],
#        [Fraction(758, 2475), Fraction(1717, 2475)],
#        [Fraction(6163, 19800), Fraction(13637, 19800)],
#        [Fraction(3131, 9900), Fraction(6769, 9900)],
#        [Fraction(6361, 19800), Fraction(13439, 19800)],
#        [Fraction(323, 990), Fraction(667, 990)],
#        [Fraction(6559, 19800), Fraction(13241, 19800)],
#        [Fraction(3329, 9900), Fraction(6571, 9900)],
#        [Fraction(6757, 19800), Fraction(13043, 19800)],
#        [Fraction(857, 2475), Fraction(1618, 2475)],
#        [Fraction(1391, 3960), Fraction(2569, 3960)],
#        [Fraction(3527, 9900), Fraction(6373, 9900)],
#        [Fraction(7153, 19800), Fraction(12647, 19800)],
#        [Fraction(1813, 4950), Fraction(3137, 4950)],
#        [Fraction(7351, 19800), Fraction(12449, 19800)],
#        [Fraction(149, 396), Fraction(247, 396)],
#        [Fraction(7549, 19800), Fraction(12251, 19800)],
#        [Fraction(956, 2475), Fraction(1519, 2475)],
#        [Fraction(7747, 19800), Fraction(12053, 19800)],
#        [Fraction(3923, 9900), Fraction(5977, 9900)],
#        [Fraction(1589, 3960), Fraction(2371, 3960)],
#        [Fraction(2011, 4950), Fraction(2939, 4950)],
#        [Fraction(8143, 19800), Fraction(11657, 19800)],
#        [Fraction(4121, 9900), Fraction(5779, 9900)],
#        [Fraction(8341, 19800), Fraction(11459, 19800)],
#        [Fraction(211, 495), Fraction(284, 495)],
#        [Fraction(8539, 19800), Fraction(11261, 19800)],
#        [Fraction(4319, 9900), Fraction(5581, 9900)],
#        [Fraction(8737, 19800), Fraction(11063, 19800)],
#        [Fraction(2209, 4950), Fraction(2741, 4950)],
#        [Fraction(1787, 3960), Fraction(2173, 3960)],
#        [Fraction(4517, 9900), Fraction(5383, 9900)],
#        [Fraction(9133, 19800), Fraction(10667, 19800)],
#        [Fraction(1154, 2475), Fraction(1321, 2475)],
#        [Fraction(9331, 19800), Fraction(10469, 19800)],
#        [Fraction(943, 1980), Fraction(1037, 1980)],
#        [Fraction(9529, 19800), Fraction(10271, 19800)],
#        [Fraction(2407, 4950), Fraction(2543, 4950)],
#        [Fraction(9727, 19800), Fraction(10073, 19800)],
#        [Fraction(4913, 9900), Fraction(4987, 9900)]], dtype=object)
#  array([[Fraction(1, 796), Fraction(795, 796)],
#        [Fraction(249, 39800), Fraction(39551, 39800)],
#        [Fraction(56, 4975), Fraction(4919, 4975)],
#        [Fraction(647, 39800), Fraction(39153, 39800)],
#        [Fraction(423, 19900), Fraction(19477, 19900)],
#        [Fraction(209, 7960), Fraction(7751, 7960)],
#        [Fraction(311, 9950), Fraction(9639, 9950)],
#        [Fraction(1443, 39800), Fraction(38357, 39800)],
#        [Fraction(821, 19900), Fraction(19079, 19900)],
#        [Fraction(1841, 39800), Fraction(37959, 39800)],
#        [Fraction(51, 995), Fraction(944, 995)],
#        [Fraction(2239, 39800), Fraction(37561, 39800)],
#        [Fraction(1219, 19900), Fraction(18681, 19900)],
#        [Fraction(2637, 39800), Fraction(37163, 39800)],
#        [Fraction(709, 9950), Fraction(9241, 9950)],
#        [Fraction(607, 7960), Fraction(7353, 7960)],
#        [Fraction(1617, 19900), Fraction(18283, 19900)],
#        [Fraction(3433, 39800), Fraction(36367, 39800)],
#        [Fraction(454, 4975), Fraction(4521, 4975)],
#        [Fraction(3831, 39800), Fraction(35969, 39800)],
#        [Fraction(403, 3980), Fraction(3577, 3980)],
#        [Fraction(4229, 39800), Fraction(35571, 39800)],
#        [Fraction(1107, 9950), Fraction(8843, 9950)],
#        [Fraction(4627, 39800), Fraction(35173, 39800)],
#        [Fraction(2413, 19900), Fraction(17487, 19900)],
#        [Fraction(201, 1592), Fraction(1391, 1592)],
#        [Fraction(653, 4975), Fraction(4322, 4975)],
#        [Fraction(5423, 39800), Fraction(34377, 39800)],
#        [Fraction(2811, 19900), Fraction(17089, 19900)],
#        [Fraction(5821, 39800), Fraction(33979, 39800)],
#        [Fraction(301, 1990), Fraction(1689, 1990)],
#        [Fraction(6219, 39800), Fraction(33581, 39800)],
#        [Fraction(3209, 19900), Fraction(16691, 19900)],
#        [Fraction(6617, 39800), Fraction(33183, 39800)],
#        [Fraction(852, 4975), Fraction(4123, 4975)],
#        [Fraction(1403, 7960), Fraction(6557, 7960)],
#        [Fraction(3607, 19900), Fraction(16293, 19900)],
#        [Fraction(7413, 39800), Fraction(32387, 39800)],
#        [Fraction(1903, 9950), Fraction(8047, 9950)],
#        [Fraction(7811, 39800), Fraction(31989, 39800)],
#        [Fraction(801, 3980), Fraction(3179, 3980)],
#        [Fraction(8209, 39800), Fraction(31591, 39800)],
#        [Fraction(1051, 4975), Fraction(3924, 4975)],
#        [Fraction(8607, 39800), Fraction(31193, 39800)],
#        [Fraction(4403, 19900), Fraction(15497, 19900)],
#        [Fraction(1801, 7960), Fraction(6159, 7960)],
#        [Fraction(2301, 9950), Fraction(7649, 9950)],
#        [Fraction(9403, 39800), Fraction(30397, 39800)],
#        [Fraction(4801, 19900), Fraction(15099, 19900)],
#        [Fraction(9801, 39800), Fraction(29999, 39800)],
#        [Fraction(50, 199), Fraction(149, 199)],
#        [Fraction(10199, 39800), Fraction(29601, 39800)],
#        [Fraction(5199, 19900), Fraction(14701, 19900)],
#        [Fraction(10597, 39800), Fraction(29203, 39800)],
#        [Fraction(2699, 9950), Fraction(7251, 9950)],
#        [Fraction(2199, 7960), Fraction(5761, 7960)],
#        [Fraction(5597, 19900), Fraction(14303, 19900)],
#        [Fraction(11393, 39800), Fraction(28407, 39800)],
#        [Fraction(1449, 4975), Fraction(3526, 4975)],
#        [Fraction(11791, 39800), Fraction(28009, 39800)],
#        [Fraction(1199, 3980), Fraction(2781, 3980)],
#        [Fraction(12189, 39800), Fraction(27611, 39800)],
#        [Fraction(3097, 9950), Fraction(6853, 9950)],
#        [Fraction(12587, 39800), Fraction(27213, 39800)],
#        [Fraction(6393, 19900), Fraction(13507, 19900)],
#        [Fraction(2597, 7960), Fraction(5363, 7960)],
#        [Fraction(1648, 4975), Fraction(3327, 4975)],
#        [Fraction(13383, 39800), Fraction(26417, 39800)],
#        [Fraction(6791, 19900), Fraction(13109, 19900)],
#        [Fraction(13781, 39800), Fraction(26019, 39800)],
#        [Fraction(699, 1990), Fraction(1291, 1990)],
#        [Fraction(14179, 39800), Fraction(25621, 39800)],
#        [Fraction(7189, 19900), Fraction(12711, 19900)],
#        [Fraction(14577, 39800), Fraction(25223, 39800)],
#        [Fraction(1847, 4975), Fraction(3128, 4975)],
#        [Fraction(599, 1592), Fraction(993, 1592)],
#        [Fraction(7587, 19900), Fraction(12313, 19900)],
#        [Fraction(15373, 39800), Fraction(24427, 39800)],
#        [Fraction(3893, 9950), Fraction(6057, 9950)],
#        [Fraction(15771, 39800), Fraction(24029, 39800)],
#        [Fraction(1597, 3980), Fraction(2383, 3980)],
#        [Fraction(16169, 39800), Fraction(23631, 39800)],
#        [Fraction(2046, 4975), Fraction(2929, 4975)],
#        [Fraction(16567, 39800), Fraction(23233, 39800)],
#        [Fraction(8383, 19900), Fraction(11517, 19900)],
#        [Fraction(3393, 7960), Fraction(4567, 7960)],
#        [Fraction(4291, 9950), Fraction(5659, 9950)],
#        [Fraction(17363, 39800), Fraction(22437, 39800)],
#        [Fraction(8781, 19900), Fraction(11119, 19900)],
#        [Fraction(17761, 39800), Fraction(22039, 39800)],
#        [Fraction(449, 995), Fraction(546, 995)],
#        [Fraction(18159, 39800), Fraction(21641, 39800)],
#        [Fraction(9179, 19900), Fraction(10721, 19900)],
#        [Fraction(18557, 39800), Fraction(21243, 39800)],
#        [Fraction(4689, 9950), Fraction(5261, 9950)],
#        [Fraction(3791, 7960), Fraction(4169, 7960)],
#        [Fraction(9577, 19900), Fraction(10323, 19900)],
#        [Fraction(19353, 39800), Fraction(20447, 39800)],
#        [Fraction(2444, 4975), Fraction(2531, 4975)],
#        [Fraction(19751, 39800), Fraction(20049, 39800)]], dtype=object)]
# <ipython-input-80-100ba28bc5bb>:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   print(np.array(refs))
# <ipython-input-80-100ba28bc5bb>:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   print(np.array(actions))
