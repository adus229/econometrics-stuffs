# %%
from fractions import Fraction
import random

# %% [markdown]
# # Locations games avec références sans numpy

# %%
message_success = "Tout est en norme avec la théorie"  

def lancer_programme_ref():
    """
    Lance un mini-programme en console pour simuler les équilibre de Nash en locations games avec références
    """
    #Demander les informations à l'utilisateur
    c = input("Entrez le côut de déviation c qui doit être compris entre 1/2 et 15 : \n")
    n = input("Sur une échelle de combien voulez-vous testez les références(100 par défaut)?\n")
    nbre_deviations = input("Entrez le nombre de déviations, par défaut il est de 100\nAppuyez sur la touche entrée si vous voulez laisser la valeur par défaut:\n")
    #Réécrire les paramètres selon l'entrée de l'utilisateur
    n= 10 if n=='' else int(n)
    nbre_deviations = 10000 if nbre_deviations=='' else int(nbre_deviations)
    #Lancer la simulation
    tester_equilibres_ref(Fraction(c),n,int(nbre_deviations))
    
def tester_equilibres_ref(c,n=100,nbre_deviations=100):
    r1_list = []
    r2_list = []
    colors = []
    grille =[Fraction(x,n) for x in range(0,n+1)]
    references = []
    for r1 in grille :
        grille_r2 = list(filter(lambda x: x>=r1,grille))
        for r2 in grille_r2:
            references.append([r1,r2])
            #print("\n*******(",r1,"=",float(r1),",",r2,"=",float(r2),")*********")
            nombres_aleatoires=[]
            result_verification  =  verifier_profile_ref(c,[r1,r2],nbre_deviations)
            if result_verification != None and result_verification["result"]==True:
                r1_list.append(r1)
                r2_list.append(r2)
                colors.append(result_verification["col"])
    #print(message_success)
    verifier_profile_ref(c,references,nbre_deviations)
    plt.scatter(r2_list,r1_list,c=colors)
    plt.title("Nuage de points des références")
    plt.show()

# %%
def verifier_profile_ref(c,refs,nbres_deviation =  10): 
    """
    Duopole avec reference
        Permet de vérifier la théorie sur l'existence des équilibres de Nash
    Paramètres:
        c: int
            Le côut de déviation, est un entier ou décimal compris entre 0.5 et 15
        refs: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
        nbre_deviation: Représente le nombre de déviation simulé. la valeur par défaut est 10 000
    return: None
    """
    borne1,borne2 = calculs_bornes(c,refs)
    if borne1>=borne2 :
        return verifier_cas1(c,refs,nbres_deviation)
    else:
        return verifier_cas2(c,refs,nbres_deviation)

# %%
def calculs_bornes (c,references):
    """
    Retourne les bornes de décision d'équilibre de Nash pour les joueurs, ie 
    r1 + 1/4c et r2 - 1/4c
    
    paramètres:
        refs: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1, ranger dans l'ordre croissant
    return: tuple
        retourne les bornes        
    """
    refs = sorted(references)
    return refs[0] + Fraction(1,4*c),refs[1] - Fraction(1,4*c)

def verifier_cas1(c,refs,nbres_deviation):
    """
    Duopole avec références:
        Permet de vérifier si le profil (1/2,1/2) est un équilibre de Nash ou pas
    Paramètres:
        c: Le côut de déviation, est un entier ou décimal compris entre 0.5 et 15
        refs[list]: les références décimales ou fraction compris entre 0 et 1
        nbre_deviation: Représente le nombre de déviation simulé 
    return: None
    """
    #print("premier cas")
    borne1,borne2 = calculs_bornes(c,refs)
    actions = [Fraction(1,2),Fraction(1,2)]
    if 1/2 >= borne2 and 1/2 <= borne1 :
        #print("paiements_actuels",[float(x)for x in paiements_actuels])
        for i in range(nbres_deviation):
            result_deviation = joueurs_peut_devier_ref(c,actions,refs)
            if result_deviation != False:
                return print(get_message_danger(result_deviation)) 
        #print("Premier cas avec 1/2, 1/2 est dans l'intervalle")
        #print(actions,"est un équilibre potentiel")
        return {"result": True, "col": 'b'}
    else:
        #print("Premier cas avec:  1/2, 1/2 n'est pas dans l'intervalle")
        for i in range(nbres_deviation):
            if joueurs_peut_devier_ref(c,actions,refs) != False:
                #print("(1/2,1/2) n'est pas un équilibre")
                return {"result": True, "col": 'w'}
        print("(1/2,1/2) ne devrait pas être un équilibre ")

        
def verifier_cas2(c,refs,nbres_deviation):
    """
    Duopole avec références:
        Permet de vérifier si le profil des bornes est bien un équilibre de Nash ou pas
    Paramètres:
        c: Le côut de déviation, est un entier ou décimal compris entre 0.5 et 15
        refs[list]: les références décimales ou fraction compris entre 0 et 1
        nbre_deviation: Représente le nombre de déviation simulé 
    return: None
    """
    equilibres = calculs_bornes(c,refs)
    eq1=c*(refs[1]- refs[0])**2 +refs[1] + refs[0] - 1 - Fraction(1,4*c)
    eq2= c*(refs[1] - refs[0])**2 - (refs[1] + refs[0]) + 1 - Fraction(1,4*c)
    if eq1 >=0 and eq2 >= 0:
        for i in range(nbres_deviation):
            result_deviation = joueurs_peut_devier_ref(c,equilibres,refs)
            #Aucune déviation ne doit être trouvée
            if result_deviation != False:
                return get_message_danger(result_deviation)
        #Si aucune déviation n'est trouvée
        #print("deuxième cas avec eq1 et eq2 vérifiées")
        #print(equilibres, "est un équilibre potentiel")
        return {"result": True, "col": 'm'}
    else:
        #print("deuxième cas avec eq1 et eq2 non vérifiées")
        for i in range(nbres_deviation):
            if joueurs_peut_devier_ref(c,equilibres,refs) != False:
                #print(equilibres, "n'est pas un équilibre")
                return {"result": True, "col": 'w'}
        print(equilibres," ne devrait pas être un équilibre, mais c'est le cas\n reférences:",refs)

# %%
def paiement_ref(c,actions,refs):
    """
    Calcule le paiement des deux joueurs et renvoie le résultat dans l'ordre des actions
    Paramètres:
        c: int, float
            Le côut de déviation doit compris entre 0.5 et 15
        actions: list, tuple
            le profil d'actions des joueurs
        refs: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
    return: list
        les paiements des joueurs
    """
    
    #Trier les actions des joueurs
    actions_triees= sorted(actions)
    
    #Vérifier si les actions étaient déjà dans le bon ordre
    is_ordered = actions_triees[0] == actions[0]
    
    #Calculer la moyenne des actions
    moyenne = (actions_triees[0]+actions_triees[1])/2 
    
    #calculer le paiement du joueur ayant joué la plus petite action
    paiement_1 = moyenne - c*(actions_triees[0]-refs[0 if is_ordered else 1])**2
    
    #Calculer le paiement du joueur ayant joué la plus grande action
    paiement_2 = 1- moyenne - c*(actions_triees[1]-refs[1 if is_ordered else 0])**2
    
    """
    Selon que la liste était déjà triée ou pas on retourne les paiements selon l'ordre dans lequel 
    les actions fût envoyées
    """
    if is_ordered:
        return [paiement_1,paiement_2]
    else :
        return [paiement_2,paiement_1]


def joueurs_peut_devier_ref(c,actions,refs):
    """
    Retourne une valeur indiquant si un joueur, a une déviation profitable ou non
    Paramètres:
      c: int, float
            Le côut de déviation doit compris entre 0.5 et 15
        actions: list, tuple
            le profil d'actions des joueurs
        refs: list, tuple
            les références des joueurs en décimales ou fraction compris entre 0 et 1 
    return: boolean,dict
        Retourne False, si aucun joueurs n'a de déviation profitable possible
        Un dict, si un joueur a une déviation profitable possible
    """
    #Le paiement des joueurs à l'équilibre
    paiements_equilibre = paiement_ref(c,actions,refs) 
    
    #On tire au hasard un joueur pour dévier
    joueur = random.randint(0,1)

    deviation = Fraction(round(random.uniform(0,1)*10000),10000)

    #On affecte cette déviation au joueur tiré au hasard précédement
    actions_deviation = list(actions)
    
    actions_deviation[joueur] = deviation

    #On calcule le paiement obtenue après la déviation
    paiement_deviation = paiement_ref(c,actions_deviation,refs)[joueur]
    
    #print("paiements ", deviation)
    
    #Si le paiement de déviation est plus grand, alors ce n'est pas un équilibre de Nash
    if paiement_deviation>paiements_equilibre[joueur]:
        return {
            "c":c,
            "refs": refs,
            "joueur": joueur,
            "paiement_equilibre": paiements_equilibre[joueur],
            "reference": refs[joueur],
            "deviation": deviation,
            "actions": actions,
            "paiement_deviation": paiement_deviation}
    return False

    
def get_message_danger(result):
    """
    Message envoyé dans le cas où on trouve une contradictionavec la théorie
    """
    return """
    *************Données**********
    Références:        {result[refs]}
    actions:           {result[actions]}
    côut de défiation: {result[c]}
    ******************************
    Le joueurs {joueur} ayant pour référence {result[reference]} et ayant joué {action_joueur}  peut dévier
    vers: {result[deviation]}
    Son paiement sans déviation est: {result[paiement_equilibre]}
    Son paiement après déviation est: {result[paiement_deviation]}
    """.format(result=result,action_joueur=result["actions"][result["joueur"]],joueur=result["joueur"]+1)

# %%
tester_equilibres_ref(2)
# Out:
# (Fraction(1, 8), Fraction(81, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(0, 1), Fraction(53, 100)]
# (Fraction(1, 8), Fraction(83, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(0, 1), Fraction(27, 50)]
# (Fraction(27, 200), Fraction(71, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 100), Fraction(12, 25)]
# (Fraction(27, 200), Fraction(83, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 100), Fraction(27, 50)]
# (Fraction(31, 200), Fraction(3, 8))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 100), Fraction(1, 2)]
# (Fraction(31, 200), Fraction(83, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 100), Fraction(27, 50)]
# (Fraction(31, 200), Fraction(17, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 100), Fraction(11, 20)]
# (Fraction(33, 200), Fraction(79, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 25), Fraction(13, 25)]
# (Fraction(33, 200), Fraction(17, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 25), Fraction(11, 20)]
# (Fraction(7, 40), Fraction(17, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 20), Fraction(11, 20)]
# (Fraction(37, 200), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 50), Fraction(14, 25)]
# (Fraction(39, 200), Fraction(79, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(7, 100), Fraction(13, 25)]
# (Fraction(41, 200), Fraction(17, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(2, 25), Fraction(11, 20)]
# (Fraction(41, 200), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(2, 25), Fraction(14, 25)]
# (Fraction(43, 200), Fraction(89, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(9, 100), Fraction(57, 100)]
# (Fraction(9, 40), Fraction(89, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 10), Fraction(57, 100)]
# (Fraction(47, 200), Fraction(83, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(11, 100), Fraction(27, 50)]
# (Fraction(49, 200), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 25), Fraction(14, 25)]
# (Fraction(49, 200), Fraction(91, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 25), Fraction(29, 50)]
# (Fraction(51, 200), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(13, 100), Fraction(14, 25)]
# (Fraction(11, 40), Fraction(17, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 20), Fraction(11, 20)]
# (Fraction(11, 40), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 20), Fraction(14, 25)]
# (Fraction(11, 40), Fraction(91, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 20), Fraction(29, 50)]
# (Fraction(57, 200), Fraction(89, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(4, 25), Fraction(57, 100)]
# (Fraction(57, 200), Fraction(93, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(4, 25), Fraction(59, 100)]
# (Fraction(59, 200), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(17, 100), Fraction(14, 25)]
# (Fraction(59, 200), Fraction(89, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(17, 100), Fraction(57, 100)]
# (Fraction(59, 200), Fraction(91, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(17, 100), Fraction(29, 50)]
# (Fraction(61, 200), Fraction(93, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(9, 50), Fraction(59, 100)]
# (Fraction(63, 200), Fraction(87, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(19, 100), Fraction(14, 25)]
# (Fraction(13, 40), Fraction(19, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 5), Fraction(3, 5)]
# (Fraction(67, 200), Fraction(89, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 100), Fraction(57, 100)]
# (Fraction(67, 200), Fraction(91, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 100), Fraction(29, 50)]
# (Fraction(71, 200), Fraction(83, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 100), Fraction(27, 50)]
# (Fraction(71, 200), Fraction(93, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 100), Fraction(59, 100)]
# (Fraction(73, 200), Fraction(89, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(6, 25), Fraction(57, 100)]
# (Fraction(73, 200), Fraction(93, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(6, 25), Fraction(59, 100)]
# (Fraction(73, 200), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(6, 25), Fraction(61, 100)]
# (Fraction(3, 8), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(1, 4), Fraction(61, 100)]
# (Fraction(77, 200), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(13, 50), Fraction(61, 100)]
# (Fraction(79, 200), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(27, 100), Fraction(61, 100)]
# (Fraction(81, 200), Fraction(19, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(7, 25), Fraction(3, 5)]
# (Fraction(83, 200), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(29, 100), Fraction(61, 100)]
# (Fraction(17, 40), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(3, 10), Fraction(31, 50)]
# (Fraction(87, 200), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(31, 100), Fraction(61, 100)]
# (Fraction(87, 200), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(31, 100), Fraction(31, 50)]
# (Fraction(89, 200), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(8, 25), Fraction(61, 100)]
# (Fraction(89, 200), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(8, 25), Fraction(31, 50)]
# (Fraction(91, 200), Fraction(93, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(33, 100), Fraction(59, 100)]
# (Fraction(91, 200), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(33, 100), Fraction(31, 50)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(93, 200), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(17, 50), Fraction(31, 50)]
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(19, 40), Fraction(97, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(7, 20), Fraction(61, 100)]
# (Fraction(19, 40), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(7, 20), Fraction(31, 50)]
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(97, 200), Fraction(99, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(9, 25), Fraction(31, 50)]
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(101, 200), Fraction(103, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(19, 50), Fraction(16, 25)]
# (Fraction(101, 200), Fraction(21, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(19, 50), Fraction(13, 20)]
# (Fraction(101, 200), Fraction(107, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(19, 50), Fraction(33, 50)]
# (Fraction(101, 200), Fraction(109, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(19, 50), Fraction(67, 100)]
# (Fraction(101, 200), Fraction(23, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(19, 50), Fraction(7, 10)]
# (Fraction(103, 200), Fraction(21, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(39, 100), Fraction(13, 20)]
# (Fraction(103, 200), Fraction(23, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(39, 100), Fraction(7, 10)]
# (Fraction(103, 200), Fraction(119, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(39, 100), Fraction(18, 25)]
# (Fraction(103, 200), Fraction(123, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(39, 100), Fraction(37, 50)]
# (Fraction(103, 200), Fraction(5, 8))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(39, 100), Fraction(3, 4)]
# (Fraction(103, 200), Fraction(127, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(39, 100), Fraction(19, 25)]
# (Fraction(21, 40), Fraction(119, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(2, 5), Fraction(18, 25)]
# (Fraction(21, 40), Fraction(123, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(2, 5), Fraction(37, 50)]
# (Fraction(21, 40), Fraction(127, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(2, 5), Fraction(19, 25)]
# (Fraction(21, 40), Fraction(27, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(2, 5), Fraction(4, 5)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(107, 200), Fraction(111, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(17, 25)]
# (Fraction(107, 200), Fraction(5, 8))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(3, 4)]
# (Fraction(107, 200), Fraction(129, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(77, 100)]
# (Fraction(107, 200), Fraction(131, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(39, 50)]
# (Fraction(107, 200), Fraction(27, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(4, 5)]
# (Fraction(107, 200), Fraction(141, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(83, 100)]
# (Fraction(107, 200), Fraction(143, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(41, 100), Fraction(21, 25)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(109, 200), Fraction(123, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 50), Fraction(37, 50)]
# (Fraction(109, 200), Fraction(139, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 50), Fraction(41, 50)]
# (Fraction(109, 200), Fraction(143, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 50), Fraction(21, 25)]
# (Fraction(109, 200), Fraction(29, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 50), Fraction(17, 20)]
# (Fraction(109, 200), Fraction(147, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 50), Fraction(43, 50)]
# (Fraction(109, 200), Fraction(151, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(21, 50), Fraction(22, 25)]
# (Fraction(111, 200), Fraction(153, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(43, 100), Fraction(89, 100)]
# (Fraction(111, 200), Fraction(157, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(43, 100), Fraction(91, 100)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(113, 200), Fraction(127, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(11, 25), Fraction(19, 25)]
# (Fraction(113, 200), Fraction(31, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(11, 25), Fraction(9, 10)]
# (Fraction(113, 200), Fraction(157, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(11, 25), Fraction(91, 100)]
# (Fraction(113, 200), Fraction(161, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(11, 25), Fraction(93, 100)]
# (Fraction(113, 200), Fraction(163, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(11, 25), Fraction(47, 50)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(23, 40), Fraction(33, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(9, 20), Fraction(19, 20)]
# (Fraction(23, 40), Fraction(167, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(9, 20), Fraction(24, 25)]
# (Fraction(23, 40), Fraction(169, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(9, 20), Fraction(97, 100)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(117, 200), Fraction(159, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 50), Fraction(23, 25)]
# (Fraction(117, 200), Fraction(33, 40))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 50), Fraction(19, 20)]
# (Fraction(117, 200), Fraction(169, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 50), Fraction(97, 100)]
# (Fraction(117, 200), Fraction(171, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 50), Fraction(49, 50)]
# (Fraction(117, 200), Fraction(7, 8))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(23, 50), Fraction(1, 1)]
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(121, 200), Fraction(167, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(12, 25), Fraction(24, 25)]
# (Fraction(121, 200), Fraction(169, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(12, 25), Fraction(97, 100)]
# (Fraction(121, 200), Fraction(171, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(12, 25), Fraction(49, 50)]
# (Fraction(121, 200), Fraction(173, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(12, 25), Fraction(99, 100)]
# (1/2,1/2) ne devrait pas être un équilibre
# (Fraction(123, 200), Fraction(169, 200))  ne devrait pas être un équilibre, mais c'est le cas
#  reférences: [Fraction(49, 100), Fraction(97, 100)]
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# (1/2,1/2) ne devrait pas être un équilibre
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-25b91528c3e8> in <module>
# ----> 1 tester_equilibres_ref(2)
#
# <ipython-input-7-180f4acb248e> in tester_equilibres_ref(c, n, nbre_deviations)
#      33                 colors.append(result_verification["col"])
#      34     #print(message_success)
# ---> 35     verifier_profile_ref(c,references,nbre_deviations)
#      36     plt.scatter(r2_list,r1_list,c=colors)
#      37     plt.title("Nuage de points des références")
#
# <ipython-input-8-bbdc361a647d> in verifier_profile_ref(c, refs, nbres_deviation)
#      11     return: None
#      12     """
# ---> 13     borne1,borne2 = calculs_bornes(c,refs)
#      14     if borne1>=borne2 :
#      15         return verifier_cas1(c,refs,nbres_deviation)
#
# <ipython-input-9-18c95784b0ef> in calculs_bornes(c, references)
#      11     """
#      12     refs = sorted(references)
# ---> 13     return refs[0] + Fraction(1,4*c),refs[1] - Fraction(1,4*c)
#      14
#      15 def verifier_cas1(c,refs,nbres_deviation):
#
# TypeError: can only concatenate list (not "Fraction") to list
